# %% [markdown]
# # Assignment Task-1 (Basic Python Programming)

# %% [markdown]
# ### Q1. Say "Hello, World!" With Python
# Task
# - print --> Hello, World!

# %%
String = "Hello, World!"

# %%
print(String)
# Out:
# Hello, World!

# %% [markdown]
# ### Q2. Python If-Else
# Task
# - Given an integer, n, perform the following conditional actions:
#
# - If n is odd, print Weird
# - If n is even and in the inclusive range of 2 to 5, print Not Weird
# - If n is even and in the inclusive range of 6 to 20, print Weird
# - If n is even and greater than 20, print Not Weird

# %%
def function(number):
    if number%2 != 0:
        print("Weird")
    else:
        if number >= 2 and number <= 5:
            print("Not Weird")
        elif number >= 6 and number <= 20:
            print("Weird")
        else:
            print("Not Weird")

# %%
function(24)
# Out:
# Not Weird

# %% [markdown]
# ### Q3. Arithmetic Operators
# Task
# - The provided code stub reads two integers from STDIN, a and b. Add code to print three lines where:
#
# - The first line contains the sum of the two numbers.
# - The second line contains the difference of the two numbers (first - second).
# - The third line contains the product of the two numbers.

# %%
a = int(input())
b = int(input())

def add_sub_product(a, b):
    print(f"Addition a and b = {a+b}")
    print(f"Difference a and b = {a-b}")
    print(f"Product a and b = {a*b}")
    
add_sub_product(a, b)
# Out:
#  3
#  5
# Addition a and b = 8
# Difference a and b = -2
# Product a and b = 15

# %% [markdown]
# ### Q4. Python: Division
# Task
# - The provided code stub reads two integers, a and b, from STDIN.
#
# - Add logic to print two lines. The first line should contain the result of integer division, a // b. The second line should contain the result of float division, a / b.
#
# - No rounding or formatting is necessary.

# %%
a = int(input())
b = int(input())

def division(a, b):
    print(f"Integer division = {a//b}")
    print(f"Float division = {a/b}")

division(a, b)
# Out:
#  3
#  5
# Integer division = 0
# Float division = 0.6

# %% [markdown]
# ### Q5. Loop
# Task
# - The provided code stub reads an integer, n, from STDIN. For all non-negative integers i < n, print i<sup>2.
# - Example: n = 3 is [0,1,2] = 0, 1, 4

# %%
n = int(input())

def list_squr(n):

    List = []
    for i in range(n):
        List.append(i**2)

    return List

list_squr(n)
# Out:
#  5
# [0, 1, 4, 9, 16]

# %% [markdown]
# ### Q6. Write a function
# Task
# - Given a year, determine whether it is a leap year. If it is a leap year, return the Boolean True, otherwise return False.

# %%
year = int(input())

def is_leap(year):

    if (year%4 == 0 and year%100 == 0) and (year%400 == 0) :
        return True
    else:
        return False

is_leap(year)
# Out:
#  1900
# False

# %% [markdown]
# ### Q7. Print Function
# Task
# - Without using any string methods, try to print the following:
# 123.....n
#
# - Note that "..." represents the consecutive values in between.
# - Example: n = 5,
# - Print the string = 12345

# %%
n = int(input())

def sequence_of_num(n):

    result = 0
    for i in range(1,n+1):
        result = result*10 + i
        
    return result   

sequence_of_num(n)
# Out:
#  5
# 12345
